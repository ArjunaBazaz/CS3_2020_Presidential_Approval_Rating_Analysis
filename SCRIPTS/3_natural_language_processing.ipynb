# %%
def analyze_sentiment(text):

    # Initialize the SentimentIntensityAnalyzer
    sia = SentimentIntensityAnalyzer()

    # Get the sentiment scores
    sentiment_scores = sia.polarity_scores(text)

    return sentiment_scores['pos']-sentiment_scores['neg']

# %%
import pandas as pd
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
file_path = "debate_tweets_cleaned.csv"  # Update the path if needed
df = pd.read_csv(file_path)
sia = SentimentIntensityAnalyzer()

# Function to analyze sentiment
def analyze_sentiment(text):
    sentiment_scores = sia.polarity_scores(str(text))  # Convert to string to avoid errors
    compound_score = sentiment_scores['compound']


    if compound_score >= 0.05:
        sentiment_category = "Positive"
    elif compound_score <= -0.05:
        sentiment_category = "Negative"
    else:
        sentiment_category = "Neutral"

    return compound_score, sentiment_category

# Apply sentiment analysis to each tweet
df[['Compound_Score', 'Sentiment']] = df['tweet'].apply(lambda x: pd.Series(analyze_sentiment(x)))

# Separate sentiment by candidate
sentiment_by_candidate = df.groupby(['about', 'Sentiment']).size().unstack().fillna(0)
df.to_csv("debate_tweets_with_sentiment.csv", index=False)
sentiment_by_candidate.to_csv("candidate_sentiment_summary.csv")
print("Sentiment analysis completed. Results saved as:")
print("- debate_tweets_with_sentiment.csv (individual tweet sentiment)")
print("- candidate_sentiment_summary.csv (sentiment summary by candidate)")
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# Out:
#                 created_at                                              tweet  \
# 0      2020-10-21 00:00:00  #Elecciones2020 | #JoeBiden y #DonaldTrump com...
# 1      2020-10-21 00:00:00  STU: "What we're looking at here is an organiz...
# 2      2020-10-21 00:00:00  #Trump puede perder cordón industrial por Covi...
# 3      2020-10-21 00:00:00  #Internacional | #Trump | #Melania | La primer...
# 4      2020-10-21 00:00:01  No life signs from #Trump in the last 3 hours....
# ...                    ...                                                ...
# 72174  2020-10-22 23:59:31  This where they will throw everything and the ...
# 72175  2020-10-22 23:59:39  Please read this.  How is this ok? #Democrat #...
# 72176  2020-10-22 23:59:43  #Bobulinski has me like. \n\n#PresidentialDeba...
# 72177  2020-10-22 23:59:56                                #Debates2020 #Biden
# 72178  2020-10-22 23:59:59  I am also hoping for at least one more "shut u...
#
#        likes  retweet_count  user_followers_count  \
# 0        0.0            0.0                1861.0
# 1      305.0          112.0              664092.0
# 2        1.0            3.0               28480.0
# 3        1.0            0.0                3176.0
# 4        0.0            0.0                  32.0
# ...      ...            ...                   ...
# 72174    1.0            0.0                1628.0
# 72175    0.0            0.0                  22.0
# 72176    0.0            0.0                 435.0
# 72177    0.0            0.0                 131.0
# 72178    1.0            0.0                1187.0
#
#                       user_location                   country  \
# 0      Philadelphia, PA / Miami, FL  United States of America
# 1                          New York  United States of America
# 2                   La Habana. Cuba                      Cuba
# 3           Baja California, México                    Mexico
# 4                               NaN                       NaN
# ...                             ...                       ...
# 72174                 Cleveland, OH  United States of America
# 72175                           NaN                       NaN
# 72176               Sioux Falls, SD                       NaN
# 72177                           NaN                       NaN
# 72178                      Portland  United States of America
#
#                  state  about
# 0              Florida  trump
# 1             New York  trump
# 2                  NaN  trump
# 3      Baja California  trump
# 4                  NaN  trump
# ...                ...    ...
# 72174             Ohio  biden
# 72175              NaN  biden
# 72176              NaN  biden
# 72177              NaN  biden
# 72178           Oregon  biden
#
# [72179 rows x 9 columns]
